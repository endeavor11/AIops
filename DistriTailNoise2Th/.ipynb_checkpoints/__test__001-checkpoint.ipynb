# %%
import torch
import numpy as np
import pickle

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pickle.load(open("SMD_334dim_2/machine-1-1_3dim_1.pkl",'rb'))

Testscore = torch.load("machine-1-1_3dim_1_anomalyScoreList.pth")

# %%
import mydis

# %%
mydis
# Out:
# <module 'mydis' from '/home/ly/File_zsx/FL/test/DistriTailNoise2Th/mydis.py'>

# %%
predict = mydis.DistriTailNoise2Th(Testscore[1].cpu().numpy(),-5,5,100,60,4)

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(2,1,1)
ax.plot(range(data.shape[0]),data[:,-1])

ax = fig.add_subplot(2,1,2)
ax.plot(range(data.shape[0]),predict)
